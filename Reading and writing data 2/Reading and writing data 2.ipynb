# %% [markdown]
# <h1>Чтение и запись данных</h1><br>
#
# <h2>Домашнее задание</h2><br>
#
# <h3>Описание домашнего задания и формат сдачи</h3><br>
#
# Выполните предложенные задачи — впишите свой код в ячейки после комментария ### YOUR CODE HERE ### и сохраните изменения, используя опцию Save and Checkpoint из вкладки меню File или кнопку Save and Checkpoint на панели инструментов. Итоговый файл в формате .ipynb (файл Jupyter Notebook) загрузите в личный кабинет и отправьте на проверку.

# %%
import pandas as pd
import urllib.request as req
import json
import sqlalchemy
import psycopg2
import pymongo

# %% [markdown]
# <h3>Задача 1</h3><br>
#
# Используя сервис MetaWeather узнайте, какая погода была в Лондоне 1 марта 2019 года. Для этого в первой ячейке определите идентификатор Лондона в этом сервисе, а во второй — запросите данные погоды. Обратите внимание, что сервис вернёт данные за несколько дней, а не только за 1 марта, в этой задаче это допустимо.

# %%
url = "https://www.metaweather.com/api/location/search/?query=london"

# %%
with req.urlopen(url) as session:
    response1 = session.read().decode()
    data = json.loads(response1)
data[0]
city = data[0]['woeid']
city
# Out:
# 44418

# %%
url = "https://www.metaweather.com/api/location/44418/2019/03/01"
with req.urlopen(url) as session:
    response = session.read().decode()
    data = json.loads(response)
data
# Out:
# [{'id': 4706336925286400,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2019-03-01T21:59:01.944736Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 7.593333333333334,
#   'max_temp': 12.533333333333333,
#   'the_temp': 12.055,
#   'wind_speed': 4.989812600347968,
#   'wind_direction': 271.4307338494283,
#   'air_pressure': 1017.6800000000001,
#   'humidity': 74,
#   'visibility': 6.465988626421697,
#   'predictability': 73},
#  {'id': 5349522672713728,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2019-03-01T18:57:01.981049Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 7.593333333333334,
#   'max_temp': 12.533333333333333,
#   'the_temp': 12.055,
#   'wind_speed': 5.207913275347968,
#   'wind_direction': 276.65012433988113,
#   'air_pressure': 1017.1800000000001,
#   'humidity': 73,
#   'visibility': 6.667623578302712,
#   'predictability': 73},
#  {'id': 4529216366313472,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2019-03-01T15:55:02.886405Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 7.593333333333334,
#   'max_temp': 12.533333333333333,
#   'the_temp': 12.055,
#   'wind_speed': 5.207913275347968,
#   'wind_direction': 276.65012433988113,
#   'air_pressure': 1017.1800000000001,
#   'humidity': 73,
#   'visibility': 6.667623578302712,
#   'predictability': 73},
#  {'id': 4582457049350144,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2019-03-01T12:53:01.886400Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 7.593333333333334,
#   'max_temp': 12.533333333333333,
#   'the_temp': 12.055,
#   'wind_speed': 5.207913275347968,
#   'wind_direction': 276.65012433988113,
#   'air_pressure': 1017.1800000000001,
#   'humidity': 73,
#   'visibility': 6.667623578302712,
#   'predictability': 73},
#  {'id': 6272821925773312,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2019-03-01T09:51:02.485187Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 7.593333333333334,
#   'max_temp': 12.533333333333333,
#   'the_temp': 12.185,
#   'wind_speed': 4.531241950347968,
#   'wind_direction': 271.4307338494283,
#   'air_pressure': 1017.1800000000001,
#   'humidity': 75,
#   'visibility': 7.897627853336514,
#   'predictability': 73},
#  {'id': 6733246983307264,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2019-03-01T06:49:02.512206Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 7.433333333333334,
#   'max_temp': 12.589999999999998,
#   'the_temp': 12.185,
#   'wind_speed': 4.566241950347968,
#   'wind_direction': 268.8527615569524,
#   'air_pressure': 1017.1800000000001,
#   'humidity': 75,
#   'visibility': 8.988134295713035,
#   'predictability': 73},
#  {'id': 5283973888475136,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2019-03-01T03:47:04.081975Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 7.433333333333334,
#   'max_temp': 12.589999999999998,
#   'the_temp': 12.185,
#   'wind_speed': 4.566241950347968,
#   'wind_direction': 268.8527615569524,
#   'air_pressure': 1017.1800000000001,
#   'humidity': 75,
#   'visibility': 8.988134295713035,
#   'predictability': 73},
#  {'id': 6461890077130752,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2019-03-01T00:45:01.506732Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 6.18,
#   'max_temp': 13.083333333333334,
#   'the_temp': 12.185,
#   'wind_speed': 5.078741950347968,
#   'wind_direction': 265.5928315240677,
#   'air_pressure': 1017.1800000000001,
#   'humidity': 76,
#   'visibility': 8.870073769187941,
#   'predictability': 73},
#  {'id': 5019272403222528,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2019-02-28T21:43:02.786204Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 4.816666666666666,
#   'max_temp': 13.12,
#   'the_temp': 10.530000000000001,
#   'wind_speed': 4.766299116497654,
#   'wind_direction': 275.4365418212393,
#   'air_pressure': 1018.5699999999999,
#   'humidity': 72,
#   'visibility': 8.870073769187941,
#   'predictability': 71},
#  {'id': 5690052443111424,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2019-02-28T18:41:03.649376Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 4.816666666666666,
#   'max_temp': 13.12,
#   'the_temp': 10.530000000000001,
#   'wind_speed': 4.766299116497654,
#   'wind_direction': 275.4365418212393,
#   'air_pressure': 1018.5699999999999,
#   'humidity': 72,
#   'visibility': 8.870073769187941,
#   'predictability': 71},
#  {'id': 5416007759822848,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2019-02-28T15:39:02.986260Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 4.816666666666666,
#   'max_temp': 13.12,
#   'the_temp': 10.530000000000001,
#   'wind_speed': 4.766299116497654,
#   'wind_direction': 275.4365418212393,
#   'air_pressure': 1018.5699999999999,
#   'humidity': 72,
#   'visibility': 8.870073769187941,
#   'predictability': 71},
#  {'id': 5740034386821120,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2019-02-28T12:37:05.187509Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 4.816666666666666,
#   'max_temp': 13.12,
#   'the_temp': 10.530000000000001,
#   'wind_speed': 4.766299116497654,
#   'wind_direction': 275.4365418212393,
#   'air_pressure': 1018.5699999999999,
#   'humidity': 72,
#   'visibility': 8.870073769187941,
#   'predictability': 71},
#  {'id': 6199880764620800,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2019-02-28T09:35:03.305049Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 4.816666666666666,
#   'max_temp': 13.12,
#   'the_temp': 10.559999999999999,
#   'wind_speed': 4.783076091497653,
#   'wind_direction': 269.3277648572423,
#   'air_pressure': 1019.0699999999999,
#   'humidity': 73,
#   'visibility': 12.108971108725045,
#   'predictability': 71},
#  {'id': 6692314535690240,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2019-02-28T06:33:03.521812Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 4.816666666666666,
#   'max_temp': 13.12,
#   'the_temp': 10.559999999999999,
#   'wind_speed': 4.783076091497653,
#   'wind_direction': 269.3277648572423,
#   'air_pressure': 1019.0699999999999,
#   'humidity': 73,
#   'visibility': 12.108971108725045,
#   'predictability': 71},
#  {'id': 4639409959862272,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2019-02-28T03:31:02.582850Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 4.816666666666666,
#   'max_temp': 13.12,
#   'the_temp': 10.559999999999999,
#   'wind_speed': 4.783076091497653,
#   'wind_direction': 269.3277648572423,
#   'air_pressure': 1019.0699999999999,
#   'humidity': 73,
#   'visibility': 12.108971108725045,
#   'predictability': 71},
#  {'id': 6106047808798720,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2019-02-28T00:29:01.686157Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 4.816666666666666,
#   'max_temp': 13.12,
#   'the_temp': 10.559999999999999,
#   'wind_speed': 4.783076091497653,
#   'wind_direction': 269.3277648572423,
#   'air_pressure': 1019.0699999999999,
#   'humidity': 73,
#   'visibility': 12.108971108725045,
#   'predictability': 71},
#  {'id': 4707250780241920,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2019-02-27T21:27:02.287645Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 4.816666666666666,
#   'max_temp': 13.12,
#   'the_temp': 10.559999999999999,
#   'wind_speed': 4.783076091497653,
#   'wind_direction': 269.3277648572423,
#   'air_pressure': 1019.0699999999999,
#   'humidity': 73,
#   'visibility': 12.108971108725045,
#   'predictability': 71},
#  {'id': 4583106663153664,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2019-02-27T18:25:02.249224Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 4.816666666666666,
#   'max_temp': 13.12,
#   'the_temp': 10.559999999999999,
#   'wind_speed': 4.783076091497653,
#   'wind_direction': 269.3277648572423,
#   'air_pressure': 1019.0699999999999,
#   'humidity': 73,
#   'visibility': 12.108971108725045,
#   'predictability': 71},
#  {'id': 6326324903804928,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2019-02-27T15:23:02.385151Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 4.816666666666666,
#   'max_temp': 13.12,
#   'the_temp': 10.559999999999999,
#   'wind_speed': 4.783076091497653,
#   'wind_direction': 269.3277648572423,
#   'air_pressure': 1019.0699999999999,
#   'humidity': 73,
#   'visibility': 12.108971108725045,
#   'predictability': 71},
#  {'id': 6479810526183424,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2019-02-27T12:21:03.087527Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 4.816666666666666,
#   'max_temp': 13.12,
#   'the_temp': 10.559999999999999,
#   'wind_speed': 4.783076091497653,
#   'wind_direction': 269.3277648572423,
#   'air_pressure': 1019.0699999999999,
#   'humidity': 73,
#   'visibility': 12.108971108725045,
#   'predictability': 71},
#  {'id': 5791006521819136,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-27T09:19:03.283020Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.22,
#   'max_temp': 12.64,
#   'the_temp': 10.899999999999999,
#   'wind_speed': 4.848320066682573,
#   'wind_direction': 244.0890106416922,
#   'air_pressure': 1016.325,
#   'humidity': 76,
#   'visibility': 12.108971108725045,
#   'predictability': 73},
#  {'id': 6305675372134400,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-27T06:17:02.513133Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.22,
#   'max_temp': 12.64,
#   'the_temp': 10.899999999999999,
#   'wind_speed': 4.848320066682573,
#   'wind_direction': 244.0890106416922,
#   'air_pressure': 1016.325,
#   'humidity': 76,
#   'visibility': 12.108971108725045,
#   'predictability': 73},
#  {'id': 6287004511764480,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-27T03:15:02.359250Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.22,
#   'max_temp': 12.64,
#   'the_temp': 10.79,
#   'wind_speed': 4.6414040416825735,
#   'wind_direction': 244.0890106416922,
#   'air_pressure': 1016.825,
#   'humidity': 76,
#   'visibility': 11.844888352024178,
#   'predictability': 73},
#  {'id': 5438426012712960,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-27T00:13:03.413112Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.22,
#   'max_temp': 12.64,
#   'the_temp': 10.79,
#   'wind_speed': 4.6414040416825735,
#   'wind_direction': 244.0890106416922,
#   'air_pressure': 1016.825,
#   'humidity': 76,
#   'visibility': 11.844888352024178,
#   'predictability': 73},
#  {'id': 5509471247794176,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-26T21:11:02.779216Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.22,
#   'max_temp': 12.64,
#   'the_temp': 10.96,
#   'wind_speed': 5.273336766682574,
#   'wind_direction': 244.0890106416922,
#   'air_pressure': 1016.825,
#   'humidity': 77,
#   'visibility': 11.239362125188897,
#   'predictability': 73},
#  {'id': 5508578062368768,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-26T18:09:01.946474Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.553333333333334,
#   'max_temp': 12.64,
#   'the_temp': 10.96,
#   'wind_speed': 5.023336766682574,
#   'wind_direction': 245.4113566976502,
#   'air_pressure': 1016.825,
#   'humidity': 76,
#   'visibility': 11.239362125188897,
#   'predictability': 73},
#  {'id': 5878048865910784,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-26T15:07:03.478770Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.553333333333334,
#   'max_temp': 12.64,
#   'the_temp': 10.96,
#   'wind_speed': 5.023336766682574,
#   'wind_direction': 245.4113566976502,
#   'air_pressure': 1016.825,
#   'humidity': 76,
#   'visibility': 11.239362125188897,
#   'predictability': 73},
#  {'id': 5308466946113536,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-26T12:05:02.842208Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.553333333333334,
#   'max_temp': 12.64,
#   'the_temp': 10.96,
#   'wind_speed': 5.023336766682574,
#   'wind_direction': 245.4113566976502,
#   'air_pressure': 1016.825,
#   'humidity': 76,
#   'visibility': 11.239362125188897,
#   'predictability': 73},
#  {'id': 5436851940753408,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-26T09:03:02.545219Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.553333333333334,
#   'max_temp': 12.64,
#   'the_temp': 10.96,
#   'wind_speed': 5.023336766682574,
#   'wind_direction': 245.4113566976502,
#   'air_pressure': 1016.825,
#   'humidity': 76,
#   'visibility': 11.239362125188897,
#   'predictability': 73},
#  {'id': 6095765321547776,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-26T06:01:03.247057Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.553333333333334,
#   'max_temp': 12.64,
#   'the_temp': 10.96,
#   'wind_speed': 5.023336766682574,
#   'wind_direction': 245.4113566976502,
#   'air_pressure': 1016.825,
#   'humidity': 76,
#   'visibility': 11.239362125188897,
#   'predictability': 73},
#  {'id': 5229498972766208,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-26T02:59:02.894998Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.553333333333334,
#   'max_temp': 12.64,
#   'the_temp': 10.96,
#   'wind_speed': 5.023336766682574,
#   'wind_direction': 245.4113566976502,
#   'air_pressure': 1016.825,
#   'humidity': 76,
#   'visibility': 11.239362125188897,
#   'predictability': 73},
#  {'id': 5623609567477760,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-25T23:57:02.524487Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.553333333333334,
#   'max_temp': 12.64,
#   'the_temp': 10.96,
#   'wind_speed': 5.023336766682574,
#   'wind_direction': 245.4113566976502,
#   'air_pressure': 1016.825,
#   'humidity': 76,
#   'visibility': 11.239362125188897,
#   'predictability': 73},
#  {'id': 6634182421774336,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-25T20:54:47.743703Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.553333333333334,
#   'max_temp': 12.64,
#   'the_temp': 10.96,
#   'wind_speed': 5.023336766682574,
#   'wind_direction': 245.4113566976502,
#   'air_pressure': 1016.825,
#   'humidity': 76,
#   'visibility': 11.239362125188897,
#   'predictability': 73},
#  {'id': 4563461751177216,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-25T17:51:03.118980Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.553333333333334,
#   'max_temp': 12.64,
#   'the_temp': 10.54,
#   'wind_speed': 4.922674916682574,
#   'wind_direction': 250.79190886131636,
#   'air_pressure': 1016.825,
#   'humidity': 77,
#   'visibility': 11.932191004533523,
#   'predictability': 73},
#  {'id': 6129776697802752,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-25T14:49:02.790407Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.5,
#   'max_temp': 13.096666666666666,
#   'the_temp': 10.54,
#   'wind_speed': 4.080174916682574,
#   'wind_direction': 246.75062254956066,
#   'air_pressure': 1016.825,
#   'humidity': 75,
#   'visibility': 12.177632625467272,
#   'predictability': 73},
#  {'id': 6586238305828864,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-25T11:47:03.141220Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 5.5,
#   'max_temp': 13.096666666666666,
#   'the_temp': 10.825,
#   'wind_speed': 4.236760016682574,
#   'wind_direction': 250.82444528695817,
#   'air_pressure': 1016.825,
#   'humidity': 75,
#   'visibility': 11.2244492165752,
#   'predictability': 73},
#  {'id': 6687204397023232,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'WNW',
#   'created': '2019-02-25T08:45:03.506752Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 3.7566666666666664,
#   'max_temp': 14.006666666666668,
#   'the_temp': 11.84,
#   'wind_speed': 4.985206588701981,
#   'wind_direction': 285.93852941298485,
#   'air_pressure': 1021.125,
#   'humidity': 74,
#   'visibility': 11.2244492165752,
#   'predictability': 70},
#  {'id': 4557243343175680,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NNW',
#   'created': '2019-02-25T05:43:02.244150Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 4.516666666666667,
#   'max_temp': 13.323333333333332,
#   'the_temp': 12.065000000000001,
#   'wind_speed': 5.112584238701981,
#   'wind_direction': 336.32756722186025,
#   'air_pressure': 1021.125,
#   'humidity': 77,
#   'visibility': 12.001473892467986,
#   'predictability': 70},
#  {'id': 5467988608155648,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-25T02:41:03.544346Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 6.696666666666666,
#   'max_temp': 13.79,
#   'the_temp': 12.85,
#   'wind_speed': 5.678653095957608,
#   'wind_direction': 235.2052990020877,
#   'air_pressure': 1016.6,
#   'humidity': 81,
#   'visibility': 9.564766762109283,
#   'predictability': 70},
#  {'id': 5425232175169536,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-24T23:39:04.890173Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 6.986666666666667,
#   'max_temp': 13.973333333333334,
#   'the_temp': 13.54,
#   'wind_speed': 5.305200694610144,
#   'wind_direction': 243.07461434229776,
#   'air_pressure': 1016.2,
#   'humidity': 78,
#   'visibility': 9.997862483098704,
#   'predictability': 70},
#  {'id': 5827015091421184,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-24T20:37:04.990752Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 6.986666666666667,
#   'max_temp': 13.973333333333334,
#   'the_temp': 13.54,
#   'wind_speed': 5.305200694610144,
#   'wind_direction': 243.76535735690948,
#   'air_pressure': 1016.2,
#   'humidity': 79,
#   'visibility': 9.997862483098704,
#   'predictability': 70},
#  {'id': 5708860272672768,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-24T17:35:06.399582Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 6.4433333333333325,
#   'max_temp': 13.776666666666666,
#   'the_temp': 13.54,
#   'wind_speed': 5.885200694610144,
#   'wind_direction': 245.0592329752299,
#   'air_pressure': 1016.2,
#   'humidity': 77,
#   'visibility': 9.997862483098704,
#   'predictability': 70},
#  {'id': 5659087742173184,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-24T14:33:04.514493Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 6.4433333333333325,
#   'max_temp': 13.776666666666666,
#   'the_temp': 13.54,
#   'wind_speed': 5.885200694610144,
#   'wind_direction': 245.0592329752299,
#   'air_pressure': 1016.2,
#   'humidity': 77,
#   'visibility': 9.997862483098704,
#   'predictability': 70},
#  {'id': 5722170476986368,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-24T11:31:04.720554Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 6.4433333333333325,
#   'max_temp': 13.776666666666666,
#   'the_temp': 13.54,
#   'wind_speed': 5.885200694610144,
#   'wind_direction': 245.0592329752299,
#   'air_pressure': 1016.2,
#   'humidity': 77,
#   'visibility': 9.997862483098704,
#   'predictability': 70},
#  {'id': 4758337302298624,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-24T08:29:05.848751Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 4.486666666666667,
#   'max_temp': 14.523333333333333,
#   'the_temp': 15.28,
#   'wind_speed': 5.046462790636019,
#   'wind_direction': 226.2070684430573,
#   'air_pressure': 1021.74,
#   'humidity': 76,
#   'visibility': 9.997862483098704,
#   'predictability': 70},
#  {'id': 5431390319411200,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-24T05:27:05.944338Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 4.486666666666667,
#   'max_temp': 14.523333333333333,
#   'the_temp': 15.28,
#   'wind_speed': 5.046462790636019,
#   'wind_direction': 226.2070684430573,
#   'air_pressure': 1021.74,
#   'humidity': 76,
#   'visibility': 9.997862483098704,
#   'predictability': 70},
#  {'id': 4757581388054528,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'SSW',
#   'created': '2019-02-24T02:25:05.379761Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 6.456666666666667,
#   'max_temp': 13.54,
#   'the_temp': 12.33,
#   'wind_speed': 5.506277472891647,
#   'wind_direction': 194.0794242942059,
#   'air_pressure': 1010.65,
#   'humidity': 76,
#   'visibility': 9.997862483098704,
#   'predictability': 71},
#  {'id': 5782572078465024,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'SSW',
#   'created': '2019-02-23T23:23:07.943921Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 6.516666666666667,
#   'max_temp': 13.313333333333333,
#   'the_temp': 12.33,
#   'wind_speed': 5.4762774728916455,
#   'wind_direction': 193.92726879589333,
#   'air_pressure': 1010.65,
#   'humidity': 75,
#   'visibility': 9.997862483098704,
#   'predictability': 73},
#  {'id': 6346204596142080,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'SSW',
#   'created': '2019-02-23T20:21:08.388238Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 6.8500000000000005,
#   'max_temp': 13.313333333333333,
#   'the_temp': 12.33,
#   'wind_speed': 6.142944139558312,
#   'wind_direction': 193.92726879589333,
#   'air_pressure': 1010.65,
#   'humidity': 74,
#   'visibility': 9.997862483098704,
#   'predictability': 73},
#  {'id': 6650235063369728,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-23T17:19:08.748299Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 7.3500000000000005,
#   'max_temp': 13.79,
#   'the_temp': 12.33,
#   'wind_speed': 6.156277472891646,
#   'wind_direction': 239.5062487851538,
#   'air_pressure': 1010.65,
#   'humidity': 73,
#   'visibility': 9.997862483098704,
#   'predictability': 73},
#  {'id': 6707256022269952,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-23T14:17:09.446347Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 7.3500000000000005,
#   'max_temp': 13.79,
#   'the_temp': 12.33,
#   'wind_speed': 6.156277472891646,
#   'wind_direction': 239.5062487851538,
#   'air_pressure': 1010.65,
#   'humidity': 73,
#   'visibility': 9.997862483098704,
#   'predictability': 73},
#  {'id': 4726798552137728,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-23T11:15:09.546303Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 7.3500000000000005,
#   'max_temp': 13.79,
#   'the_temp': 12.33,
#   'wind_speed': 6.156277472891646,
#   'wind_direction': 239.5062487851538,
#   'air_pressure': 1010.65,
#   'humidity': 73,
#   'visibility': 9.997862483098704,
#   'predictability': 73},
#  {'id': 5516703435849728,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-23T08:13:08.742296Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 8.106666666666667,
#   'max_temp': 13.966666666666667,
#   'the_temp': 12.86,
#   'wind_speed': 6.448186060075824,
#   'wind_direction': 243.16721174114366,
#   'air_pressure': 1007.81,
#   'humidity': 74,
#   'visibility': 9.997862483098704,
#   'predictability': 73},
#  {'id': 5602052254203904,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-23T05:11:07.151052Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 8.41,
#   'max_temp': 13.776666666666666,
#   'the_temp': 12.86,
#   'wind_speed': 6.131519393409157,
#   'wind_direction': 244.7481688554968,
#   'air_pressure': 1007.81,
#   'humidity': 76,
#   'visibility': 9.997862483098704,
#   'predictability': 73},
#  {'id': 6364505787334656,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2019-02-23T02:09:07.907919Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 8.523333333333333,
#   'max_temp': 13.573333333333332,
#   'the_temp': 12.25,
#   'wind_speed': 6.158445478406108,
#   'wind_direction': 241.98796661534055,
#   'air_pressure': 1007.17,
#   'humidity': 76,
#   'visibility': 9.997862483098704,
#   'predictability': 73},
#  {'id': 5783817618980864,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-22T23:07:10.292345Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 9.036666666666667,
#   'max_temp': 13.79,
#   'the_temp': 12.25,
#   'wind_speed': 7.795112145072775,
#   'wind_direction': 234.63049839654064,
#   'air_pressure': 1007.17,
#   'humidity': 74,
#   'visibility': 9.997862483098704,
#   'predictability': 73},
#  {'id': 5699350946643968,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-22T20:05:10.542606Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 9.036666666666667,
#   'max_temp': 13.79,
#   'the_temp': 12.25,
#   'wind_speed': 7.795112145072775,
#   'wind_direction': 234.63049839654064,
#   'air_pressure': 1007.17,
#   'humidity': 74,
#   'visibility': 9.997862483098704,
#   'predictability': 73},
#  {'id': 6400411177058304,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-22T17:03:12.079819Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 9.036666666666667,
#   'max_temp': 13.79,
#   'the_temp': 12.25,
#   'wind_speed': 8.795112145072775,
#   'wind_direction': 235.30495491409584,
#   'air_pressure': 1007.17,
#   'humidity': 74,
#   'visibility': 9.997862483098704,
#   'predictability': 73},
#  {'id': 5181285246959616,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-22T14:01:12.183147Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 9.036666666666667,
#   'max_temp': 13.79,
#   'the_temp': 12.25,
#   'wind_speed': 8.795112145072775,
#   'wind_direction': 235.30495491409584,
#   'air_pressure': 1007.17,
#   'humidity': 74,
#   'visibility': 9.997862483098704,
#   'predictability': 73},
#  {'id': 4976380410331136,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-22T10:59:11.618026Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 8.436666666666666,
#   'max_temp': 14.343333333333334,
#   'the_temp': 13.73,
#   'wind_speed': 10.436827195842945,
#   'wind_direction': 231.66653499840575,
#   'air_pressure': 1018.56,
#   'humidity': 73,
#   'visibility': 9.997862483098704,
#   'predictability': 73},
#  {'id': 5295259753906176,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-22T07:57:10.726011Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 8.436666666666666,
#   'max_temp': 14.343333333333334,
#   'the_temp': 13.73,
#   'wind_speed': 10.436827195842945,
#   'wind_direction': 231.66653499840575,
#   'air_pressure': 1018.56,
#   'humidity': 73,
#   'visibility': 9.997862483098704,
#   'predictability': 73},
#  {'id': 5940797499244544,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-22T04:55:11.683612Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 8.913333333333332,
#   'max_temp': 14.086666666666668,
#   'the_temp': 12.69,
#   'wind_speed': 9.724457435244837,
#   'wind_direction': 227.33648456423006,
#   'air_pressure': 1017.18,
#   'humidity': 72,
#   'visibility': 9.997862483098704,
#   'predictability': 73},
#  {'id': 5574560504086528,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-22T01:53:10.885460Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 8.645,
#   'max_temp': 13.48,
#   'the_temp': 12.69,
#   'wind_speed': 8.351686152867256,
#   'wind_direction': 226.0,
#   'air_pressure': 1017.18,
#   'humidity': 73,
#   'visibility': None,
#   'predictability': 75},
#  {'id': 6136049952620544,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-21T22:51:14.063982Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 8.645,
#   'max_temp': 13.48,
#   'the_temp': 12.69,
#   'wind_speed': 8.351686152867256,
#   'wind_direction': 226.0,
#   'air_pressure': 1017.18,
#   'humidity': 73,
#   'visibility': None,
#   'predictability': 75},
#  {'id': 6297506363211776,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-21T19:49:14.567745Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 8.645,
#   'max_temp': 13.48,
#   'the_temp': 12.69,
#   'wind_speed': 8.351686152867256,
#   'wind_direction': 226.0,
#   'air_pressure': 1030.66,
#   'humidity': 73,
#   'visibility': None,
#   'predictability': 75},
#  {'id': 6311801188777984,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-21T16:47:14.655054Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 8.645,
#   'max_temp': 13.48,
#   'the_temp': 12.69,
#   'wind_speed': 8.351686152867256,
#   'wind_direction': 226.0,
#   'air_pressure': 1030.66,
#   'humidity': 73,
#   'visibility': None,
#   'predictability': 75},
#  {'id': 6032668781182976,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-21T13:45:14.399134Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 8.145,
#   'max_temp': 13.48,
#   'the_temp': 12.69,
#   'wind_speed': 6.851686152867256,
#   'wind_direction': 232.49999999999997,
#   'air_pressure': 1022.67,
#   'humidity': 74,
#   'visibility': None,
#   'predictability': 75},
#  {'id': 5976721731878912,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-21T10:43:14.990412Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 8.145,
#   'max_temp': 13.48,
#   'the_temp': 12.69,
#   'wind_speed': 6.851686152867256,
#   'wind_direction': 232.49999999999997,
#   'air_pressure': 1022.67,
#   'humidity': 74,
#   'visibility': None,
#   'predictability': 75},
#  {'id': 5134166656024576,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-21T07:41:14.233862Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 8.11,
#   'max_temp': 14.21,
#   'the_temp': 14.42,
#   'wind_speed': 7.615972719319176,
#   'wind_direction': 233.99999999999997,
#   'air_pressure': 1015.89,
#   'humidity': 74,
#   'visibility': None,
#   'predictability': 75},
#  {'id': 5413591926702080,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-21T04:39:14.576062Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 8.11,
#   'max_temp': 14.21,
#   'the_temp': 14.42,
#   'wind_speed': 7.615972719319176,
#   'wind_direction': 233.99999999999997,
#   'air_pressure': 1015.89,
#   'humidity': 74,
#   'visibility': None,
#   'predictability': 75},
#  {'id': 5805840887971840,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'SW',
#   'created': '2019-02-21T01:37:13.525713Z',
#   'applicable_date': '2019-03-01',
#   'min_temp': 8.11,
#   'max_temp': 14.21,
#   'the_temp': 14.42,
#   'wind_speed': 7.615972719319176,
#   'wind_direction': 233.99999999999997,
#   'air_pressure': 1015.89,
#   'humidity': 74,
#   'visibility': None,
#   'predictability': 75}]

# %% [markdown]
# <h3>Задача 2</h3><br>
#
# Сохраните данные погоды, полученные в предыдущей задаче, в файл weather.json. При сохранении используйте четыре пробела для форматирования.

# %%
with open('weather.json', 'w') as file:
    json.dump(data, file, indent=4)

# %% [markdown]
# <h3>Задача 3</h3><br>
#
# Загрузите содержимое файла weather.json в DataFrame и выведите первые пять строк DataFrame на экран.

# %%
with open('weather.json', 'r') as file:
    s = json.load(file)
    df = pd.DataFrame(s)
df.head()
# Out:
#                  id weather_state_name weather_state_abbr  \
# 0  4706336925286400            Showers                  s
# 1  5349522672713728            Showers                  s
# 2  4529216366313472            Showers                  s
# 3  4582457049350144            Showers                  s
# 4  6272821925773312            Showers                  s
#
#   wind_direction_compass                      created applicable_date  \
# 0                      W  2019-03-01T21:59:01.944736Z      2019-03-01
# 1                      W  2019-03-01T18:57:01.981049Z      2019-03-01
# 2                      W  2019-03-01T15:55:02.886405Z      2019-03-01
# 3                      W  2019-03-01T12:53:01.886400Z      2019-03-01
# 4                      W  2019-03-01T09:51:02.485187Z      2019-03-01
#
#    min_temp   max_temp  the_temp  wind_speed  wind_direction  air_pressure  \
# 0  7.593333  12.533333    12.055    4.989813      271.430734       1017.68
# 1  7.593333  12.533333    12.055    5.207913      276.650124       1017.18
# 2  7.593333  12.533333    12.055    5.207913      276.650124       1017.18
# 3  7.593333  12.533333    12.055    5.207913      276.650124       1017.18
# 4  7.593333  12.533333    12.185    4.531242      271.430734       1017.18
#
#    humidity  visibility  predictability
# 0        74    6.465989              73
# 1        73    6.667624              73
# 2        73    6.667624              73
# 3        73    6.667624              73
# 4        75    7.897628              73

# %% [markdown]
# <h3>Задача 4</h3><br>
#
# Сохраните DataFrame из предыдущей задачи в файл result.csv. В качестве названия столбца-индекса используйте index.

# %%
df.to_csv('result.csv', index_label='index')

# %% [markdown]
# <h3>Задача 5</h3><br>
#
# Загрузите содержимое SQL-таблицы ratings в DataFrame. Выведите первые пять строк DataFrame на экран. Для подключения к БД используйте строку подключения, указанную в следующей ячейке.

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5432/db_ds_students'

engine = sqlalchemy.create_engine(conn)
connect = engine.connect()

# %%
inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
# Out:
# ['keywords',
#  'links',
#  'ratings',
#  'exploratory',
#  'new_table',
#  'course_purchases',
#  'joi',
#  'studentt']

# %%
df = pd.read_sql("select * from ratings", connect)
df.head()
# Out:
#    userid  movieid  rating   timestamp
# 0    6654     1135     3.5  1089148756
# 1    6654     1196     3.0  1087586067
# 2    6654     1220     3.5  1092195923
# 3    6654     1222     5.0  1087586478
# 4    6654     1225     5.0  1087587670

# %% [markdown]
# <h3>Задача 6</h3><br>
#
# Сохраните первые 10000 записей датафрейма из предыдущей задачи в файл result2.xlsx, при сохранении задайте листу имя MySheet.
#
# (Примечание: для указания имени листа в файле Excel как при чтении, так и при записи используется параметр sheet_name)

# %%
df.head(1000).to_excel('result2.xlsx', sheet_name='sheet', index_label='index')

# %% [markdown]
# <h3>Задача 7</h3><br>
#
# Определите количество документов в коллекции users в MongoDB. Если количество документов < 1000, то в следующей ячейке загрузите всё содержимое этой коллекции в список и выведите нулевой элемент этого списка на экран. Для подключения к MongoDB используйте строку подключения, указанную в следующей ячейке.

# %%
conn = 'mongodb://students:X63673t47Gl03Sq@dsstudents.skillbox.ru:27017/?authSource=movies'

connect = pymongo.MongoClient(conn)
db = connect['movies']
db.list_collection_names()
users = db['users']

# %%
users.find().count()
# Out:
# <ipython-input-13-bb8812d424d4>:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   users.find().count()
# 100

# %%
head = users.find()
my_list = list(head)
my_list[0]
# Out:
# {'_id': ObjectId('5cc69095067496679c74f7a4'),
#  'user_id': 'ed5da480-57a2-489c-8e68-512155ab9892',
#  'first_name': 'Жанна',
#  'last_name': 'Петрова',
#  'mail': 'zhanna_03816@gmail.com',
#  'age': 20.0}

# %% [markdown]
# <h3>Задача 8</h3><br>
#
# Преобразуйте список всех документов коллекции users из предыдущей задачи в pandas DataFrame и сохраните его содержимое в файл result3.xlsx.

# %%
df = pd.DataFrame(my_list)
df.to_excel('result3.xlsx', index_label = 'index')

# %% [markdown]
# <h2>Дополнительные (необязательные) задачи</h2>
#
# <h3>Задача 9</h3><br>
#
# Используя данные SQL-таблицы ratings, для каждого пользователя (столбец userid) определите средний рейтинг, который этот пользователь поставил фильмам. Результат выведите на экран.
#
# Группировку проведите двумя способами: с помощью GROUP BY в строке запроса к БД и с использованием метода groupby в pandas.
#
# Для подключения к БД используйте строку подключения в следующей ячейке

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5432/db_ds_students'

engine = sqlalchemy.create_engine(conn)
connect = engine.connect()

inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
# Out:
# ['keywords',
#  'links',
#  'ratings',
#  'exploratory',
#  'new_table',
#  'course_purchases',
#  'joi',
#  'studentt']

# %%
df = pd.read_sql("select * from ratings ", connect)
df.head()
# Out:
#    userid  movieid  rating   timestamp
# 0    6654     1135     3.5  1089148756
# 1    6654     1196     3.0  1087586067
# 2    6654     1220     3.5  1092195923
# 3    6654     1222     5.0  1087586478
# 4    6654     1225     5.0  1087587670

# %%
df.groupby('userid')['rating'].mean()
# Out:
# userid
# 1       4.277778
# 2       3.318182
# 3       3.100000
# 4       3.500000
# 5       4.269231
#           ...
# 7952    3.390244
# 7953    3.567568
# 7954    3.750000
# 7955    4.150000
# 7956    3.290640
# Name: rating, Length: 7956, dtype: float64

# %%
df_1 = pd.read_sql("select userid, avg(rating) from ratings group by userid", connect)
df_1.head()
# Out:
#    userid       avg
# 0    6114  4.000000
# 1    4790  4.000000
# 2     273  4.314685
# 3    3936  3.756757
# 4    5761  3.419220

# %% [markdown]
# <h3>Задача 10</h3><br>
#
# Объедините таблицы ratings и keywords по столбцам movieid (используйте левое объединение). Объединение проведите двумя способами: с помощью LEFT JOIN в строке запроса к БД и с использованием метода merge в pandas. Результат объединения загрузите в DataFrame и сохраните в файл result4.csv.
#
# Обратите внимание, что при объединении возможно дублирование столбцов. В результирующем датафрейме не должно быть таких дублированных столбцов.

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5432/db_ds_students'

engine = sqlalchemy.create_engine(conn)
connect = engine.connect()

inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
# Out:
# ['keywords',
#  'links',
#  'ratings',
#  'exploratory',
#  'new_table',
#  'course_purchases',
#  'joi',
#  'studentt']

# %%
df = pd.read_sql("select * from ratings", connect)
df_1 = pd.read_sql("select * from keywords", connect)

df_1.head()
# Out:
#    movieid                                               tags
# 0      862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1     8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2    15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3    31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4    11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
df_2 = pd.read_sql("select ratings.userid, ratings.movieid, ratings.rating, ratings.timestamp, keywords.tags from ratings left join keywords on ratings.movieid = keywords.movieid", connect)
df_2
# Out:
#          userid  movieid  rating   timestamp  \
# 0          6654     1196     3.0  1087586067
# 1          6654     1220     3.5  1092195923
# 2          6654     1222     5.0  1087586478
# 3          6654     1265     4.0  1087586737
# 4          6654     1265     4.0  1087586737
# ...         ...      ...     ...         ...
# 2236573    6653     1094     2.5  1383012038
# 2236574    6653     1333     2.0  1383012075
# 2236575    6654      141     4.5  1092196108
# 2236576    6654      141     4.5  1092196108
# 2236577    6654     1094     2.5  1087587416
#
#                                                       tags
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3        [{'id': 1155, 'name': 'brother sister relation...
# 4        [{'id': 1155, 'name': 'brother sister relation...
# ...                                                    ...
# 2236573                                               None
# 2236574                                               None
# 2236575  [{'id': 970, 'name': 'parent child relationshi...
# 2236576  [{'id': 970, 'name': 'parent child relationshi...
# 2236577                                               None
#
# [2236578 rows x 5 columns]

# %%
df_2.to_csv('result4.csv')

# %%
df_1.merge(df, on='movieid')
df
# Out:
#          userid  movieid  rating   timestamp
# 0          6654     1135     3.5  1089148756
# 1          6654     1196     3.0  1087586067
# 2          6654     1220     3.5  1092195923
# 3          6654     1222     5.0  1087586478
# 4          6654     1225     5.0  1087587670
# ...         ...      ...     ...         ...
# 1555547    6654      953     4.5  1087585938
# 1555548    6654     1079     3.0  1087586051
# 1555549    6654     1091     4.0  1089149125
# 1555550    6654     1094     2.5  1087587416
# 1555551    6654     1099     3.5  1087587588
#
# [1555552 rows x 4 columns]

# %%
df.to_csv('result4.csv')

# %% [markdown]
# <h3>Задача 11</h3><br>
#
# Используя объединенную таблицу из предыдущего задания, найдите все идентификаторы фильмов с тегом africa (но не south africa или любые другие). Список тегов в формате JSON записан в столбце tags.

# %%
df_2[df_2['tags'] == {'id': 409, 'name': 'africa'}]
# Out:
# Empty DataFrame
# Columns: [userid, movieid, rating, timestamp, tags]
# Index: []
